# %% [markdown]
# # Greeting DS Montenegro!
# #

# %%
print(f"Hi there, {input('please input your name: ')}!")
# Out:
# Hi there, Milena!

# %% [markdown]
# - Question: How many records are in our sample below?

# %%
rows = [4,7,9,12]

len(rows)
# Out:
# 4

# %%
# The notebook is a great way to document your code and share it with others. You## Milena create a first change in notebook can add text, images, and even interactive visualizations to your notebook.

# %%
student_name = "Milena"
print(f"Notebook completed by {student_name}")
# Out:
# Notebook completed by Milena
